# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import json

# %%
business_id= []
mydata=[]
path = '/Users/bjxl/yelp_dataset/yelp_academic_dataset_business.json'

with open(path, encoding='utf-8') as fin:
    i = 0
    for line in fin:
        line_contents = json.loads(line)
        categories = line_contents['categories']
        state = line_contents['business_id']
        try:
            if 'Restaurants' in categories:
                business_id.append(business_id)
                mydata.append(line_contents)
        except TypeError:
            #print(line_contents)
            pass
print(len(business_id))
# Out:
# 52268

# %%
column_names = mydata[0].keys()
for item in mydata:
    if len([x for x in item.keys() if x in column_names]) != len(item.keys()):
        print(item.keys())
data = []
for column in column_names:
    this_col = []
    for item in mydata:
        this_col.append(item[column])
    data.append(this_col)

# %%
np.array(data[12])
print(np.array(data[12]))
# Out:
# ['Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries'
#  'Burgers, Fast Food, Sandwiches, Food, Ice Cream & Frozen Yogurt, Restaurants'
#  'Pubs, Restaurants, Italian, Bars, American (Traditional), Nightlife, Greek'
#  ... 'Restaurants, Mexican'
#  'Restaurants, Comfort Food, Food, Food Trucks, Caterers, Event Planning & Services'
#  'Middle Eastern, Restaurants']

# %%
first_cols = list(column_names)[0:10]
pd_data ={}
idx = 0
for column in first_cols:
    pd_data[column] = data[idx]
    idx+=1
business = pd.DataFrame(pd_data)
business.head()
# Out:
#               business_id                   name              address  \
# 0  MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries          935 Race St
# 1  CF33F8-E6oudUQ46HnavjQ         Sonic Drive-In        615 S Main St
# 2  k0hlBqXX-Bt0vf1op7Jr1w  Tsevi's Pub And Grill    8025 Mackenzie Rd
# 3  bBDDEgkFA1Otx9Lfe7BZUQ         Sonic Drive-In  2312 Dickerson Pike
# 4  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck
#
#            city state postal_code   latitude  longitude  stars  review_count
# 0  Philadelphia    PA       19107  39.955505 -75.155564    4.0            80
# 1  Ashland City    TN       37015  36.269593 -87.058943    2.0             6
# 2        Affton    MO       63123  38.565165 -90.321087    3.0            19
# 3     Nashville    TN       37207  36.208102 -86.768170    1.5            10
# 4     Tampa Bay    FL       33602  27.955269 -82.456320    4.0            10

# %%
def get_superset_of_column_names_from_file(data):
    column_names = set()

    for line_contents in data:
        column_names.update(
            set(get_column_names(line_contents))
        )
    return column_names


def get_column_names(line_contents):
    column_names = []
    if line_contents is None:
        return ''
    for k in line_contents.keys():
        column_names.append('{0}'.format(k) )
    return column_names

# %%
nested_columns = get_superset_of_column_names_from_file(data[11])
nested_columns
# Out:
# {'AcceptsInsurance',
#  'AgesAllowed',
#  'Alcohol',
#  'Ambience',
#  'BYOB',
#  'BYOBCorkage',
#  'BestNights',
#  'BikeParking',
#  'BusinessAcceptsBitcoin',
#  'BusinessAcceptsCreditCards',
#  'BusinessParking',
#  'ByAppointmentOnly',
#  'Caters',
#  'CoatCheck',
#  'Corkage',
#  'DietaryRestrictions',
#  'DogsAllowed',
#  'DriveThru',
#  'GoodForDancing',
#  'GoodForKids',
#  'GoodForMeal',
#  'HairSpecializesIn',
#  'HappyHour',
#  'HasTV',
#  'Music',
#  'NoiseLevel',
#  'Open24Hours',
#  'OutdoorSeating',
#  'RestaurantsAttire',
#  'RestaurantsCounterService',
#  'RestaurantsDelivery',
#  'RestaurantsGoodForGroups',
#  'RestaurantsPriceRange2',
#  'RestaurantsReservations',
#  'RestaurantsTableService',
#  'RestaurantsTakeOut',
#  'Smoking',
#  'WheelchairAccessible',
#  'WiFi'}

# %%
# make all cols zeroes first
for col in nested_columns:
    business[col]= np.nan
#loop through each attribute
idx = 0
for attr in data[11]:
    #print(idx)
    if attr is None:
        idx+=1
        continue
    for k,v in attr.items():
        #print('value: '+v)
        if'{' in v:
            continue
        business[k][idx] = v
    idx+=1
business.to_csv('/Users/bjxl/fyp/csv/business.csv')
# Out:
# /var/folders/cv/j22vlhb52tb_nhwbf2m_cdq40000gn/T/ipykernel_23505/3684019238.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   business[k][idx] = v

# %%
business
# Out:
#                   business_id                           name  \
# 0      MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1      CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 2      k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 3      bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 4      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                       ...                            ...
# 52263  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 52264  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 52265  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 52266  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 52267  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                      address             city state postal_code   latitude  \
# 0                935 Race St     Philadelphia    PA       19107  39.955505
# 1              615 S Main St     Ashland City    TN       37015  36.269593
# 2          8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 3        2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 4                                   Tampa Bay    FL       33602  27.955269
# ...                      ...              ...   ...         ...        ...
# 52263        19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 52264    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 52265          1108 S 9th St     Philadelphia    PA       19147  39.935982
# 52266        4405 Pennell Rd            Aston    DE       19014  39.856185
# 52267  2470 Guardian Road NW         Edmonton    AB     T5T 1K8  53.509649
#
#         longitude  stars  review_count  ... DietaryRestrictions Corkage  \
# 0      -75.155564    4.0            80  ...                 NaN     NaN
# 1      -87.058943    2.0             6  ...                 NaN     NaN
# 2      -90.321087    3.0            19  ...                 NaN     NaN
# 3      -86.768170    1.5            10  ...                 NaN     NaN
# 4      -82.456320    4.0            10  ...                 NaN     NaN
# ...           ...    ...           ...  ...                 ...     ...
# 52263  -75.310344    3.0            11  ...                 NaN     NaN
# 52264 -116.284689    4.0            33  ...                 NaN     NaN
# 52265  -75.158665    4.5            35  ...                 NaN     NaN
# 52266  -75.427725    4.5            14  ...                 NaN     NaN
# 52267 -113.675999    4.5            18  ...                 NaN     NaN
#
#       HappyHour BestNights AgesAllowed Open24Hours GoodForDancing  \
# 0           NaN        NaN         NaN         NaN            NaN
# 1         False        NaN         NaN         NaN            NaN
# 2           NaN        NaN         NaN         NaN            NaN
# 3         False        NaN         NaN         NaN            NaN
# 4           NaN        NaN         NaN         NaN            NaN
# ...         ...        ...         ...         ...            ...
# 52263       NaN        NaN         NaN         NaN            NaN
# 52264       NaN        NaN         NaN         NaN            NaN
# 52265     False        NaN         NaN         NaN            NaN
# 52266       NaN        NaN         NaN         NaN            NaN
# 52267       NaN        NaN         NaN         NaN            NaN
#
#            Alcohol HairSpecializesIn  NoiseLevel
# 0          u'none'               NaN         NaN
# 1          u'none'               NaN         NaN
# 2      u'full_bar'               NaN  u'average'
# 3          u'none'               NaN         NaN
# 4           'none'               NaN         NaN
# ...            ...               ...         ...
# 52263          NaN               NaN         NaN
# 52264      u'none'               NaN     u'loud'
# 52265      u'none'               NaN         NaN
# 52266       'none'               NaN         NaN
# 52267          NaN               NaN  u'average'
#
# [52268 rows x 49 columns]

# %%
restaurant=pd.read_csv("/Users/bjxl/fyp/csv/restaurant.csv")
restaurant
# Out:
#        Unnamed: 0             business_id                           name  \
# 0               0  MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1               1  CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 2               2  k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 3               3  bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 4               4  eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...           ...                     ...                            ...
# 52263       52263  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 52264       52264  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 52265       52265  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 52266       52266  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 52267       52267  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                      address             city state postal_code   latitude  \
# 0                935 Race St     Philadelphia    PA       19107  39.955505
# 1              615 S Main St     Ashland City    TN       37015  36.269593
# 2          8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 3        2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 4                        NaN        Tampa Bay    FL       33602  27.955269
# ...                      ...              ...   ...         ...        ...
# 52263        19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 52264    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 52265          1108 S 9th St     Philadelphia    PA       19147  39.935982
# 52266        4405 Pennell Rd            Aston    DE       19014  39.856185
# 52267  2470 Guardian Road NW         Edmonton    AB     T5T 1K8  53.509649
#
#         longitude  stars  review_count  is_open  \
# 0      -75.155564    4.0            80        1
# 1      -87.058943    2.0             6        1
# 2      -90.321087    3.0            19        0
# 3      -86.768170    1.5            10        1
# 4      -82.456320    4.0            10        1
# ...           ...    ...           ...      ...
# 52263  -75.310344    3.0            11        1
# 52264 -116.284689    4.0            33        1
# 52265  -75.158665    4.5            35        1
# 52266  -75.427725    4.5            14        1
# 52267 -113.675999    4.5            18        0
#
#                                               attributes  \
# 0      {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 1      {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 2      {'Caters': 'True', 'Alcohol': "u'full_bar'", '...
# 3      {'RestaurantsAttire': "'casual'", 'Restaurants...
# 4      {'Alcohol': "'none'", 'OutdoorSeating': 'None'...
# ...                                                  ...
# 52263  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 52264  {'WiFi': "'free'", 'RestaurantsGoodForGroups':...
# 52265  {'WheelchairAccessible': 'False', 'Restaurants...
# 52266  {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 52267  {'Ambience': "{'touristy': False, 'hipster': F...
#
#                                               categories  \
# 0      Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1      Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 2      Pubs, Restaurants, Italian, Bars, American (Tr...
# 3      Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 4             Vietnamese, Food, Restaurants, Food Trucks
# ...                                                  ...
# 52263  Restaurants, Sandwiches, Convenience Stores, C...
# 52264  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 52265                               Restaurants, Mexican
# 52266  Restaurants, Comfort Food, Food, Food Trucks, ...
# 52267                        Middle Eastern, Restaurants
#
#                                                    hours  sentiment_score
# 0      {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...         0.279627
# 1      {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...        -0.091565
# 2                                                    NaN         0.190637
# 3      {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...         0.046442
# 4      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...         0.189109
# ...                                                  ...              ...
# 52263  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...         0.191557
# 52264  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...         0.236078
# 52265  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...         0.338036
# 52266  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...         0.355836
# 52267  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...         0.270178
#
# [52268 rows x 16 columns]

# %%
business["sentiment_score"]=restaurant["sentiment_score"]
business
# Out:
#                   business_id                           name  \
# 0      MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1      CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 2      k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 3      bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 4      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                       ...                            ...
# 52263  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 52264  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 52265  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 52266  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 52267  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                      address             city state postal_code   latitude  \
# 0                935 Race St     Philadelphia    PA       19107  39.955505
# 1              615 S Main St     Ashland City    TN       37015  36.269593
# 2          8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 3        2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 4                                   Tampa Bay    FL       33602  27.955269
# ...                      ...              ...   ...         ...        ...
# 52263        19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 52264    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 52265          1108 S 9th St     Philadelphia    PA       19147  39.935982
# 52266        4405 Pennell Rd            Aston    DE       19014  39.856185
# 52267  2470 Guardian Road NW         Edmonton    AB     T5T 1K8  53.509649
#
#         longitude  stars  review_count  ... Corkage HappyHour BestNights  \
# 0      -75.155564    4.0            80  ...     NaN       NaN        NaN
# 1      -87.058943    2.0             6  ...     NaN     False        NaN
# 2      -90.321087    3.0            19  ...     NaN       NaN        NaN
# 3      -86.768170    1.5            10  ...     NaN     False        NaN
# 4      -82.456320    4.0            10  ...     NaN       NaN        NaN
# ...           ...    ...           ...  ...     ...       ...        ...
# 52263  -75.310344    3.0            11  ...     NaN       NaN        NaN
# 52264 -116.284689    4.0            33  ...     NaN       NaN        NaN
# 52265  -75.158665    4.5            35  ...     NaN     False        NaN
# 52266  -75.427725    4.5            14  ...     NaN       NaN        NaN
# 52267 -113.675999    4.5            18  ...     NaN       NaN        NaN
#
#       AgesAllowed Open24Hours GoodForDancing      Alcohol HairSpecializesIn  \
# 0             NaN         NaN            NaN      u'none'               NaN
# 1             NaN         NaN            NaN      u'none'               NaN
# 2             NaN         NaN            NaN  u'full_bar'               NaN
# 3             NaN         NaN            NaN      u'none'               NaN
# 4             NaN         NaN            NaN       'none'               NaN
# ...           ...         ...            ...          ...               ...
# 52263         NaN         NaN            NaN          NaN               NaN
# 52264         NaN         NaN            NaN      u'none'               NaN
# 52265         NaN         NaN            NaN      u'none'               NaN
# 52266         NaN         NaN            NaN       'none'               NaN
# 52267         NaN         NaN            NaN          NaN               NaN
#
#        NoiseLevel sentiment_score
# 0             NaN        0.279627
# 1             NaN       -0.091565
# 2      u'average'        0.190637
# 3             NaN        0.046442
# 4             NaN        0.189109
# ...           ...             ...
# 52263         NaN        0.191557
# 52264     u'loud'        0.236078
# 52265         NaN        0.338036
# 52266         NaN        0.355836
# 52267  u'average'        0.270178
#
# [52268 rows x 50 columns]

# %%
business=pd.read_csv("/Users/bjxl/fyp/csv/business.csv")
business
# Out:
# /var/folders/cv/j22vlhb52tb_nhwbf2m_cdq40000gn/T/ipykernel_35306/4047546247.py:1: DtypeWarning: Columns (24,40,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   business=pd.read_csv("/Users/bjxl/fyp/csv/business.csv")
#        Unnamed: 0             business_id                           name  \
# 0               0  MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1               1  CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 2               2  k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 3               3  bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 4               4  eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...           ...                     ...                            ...
# 52263       52263  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 52264       52264  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 52265       52265  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 52266       52266  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 52267       52267  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                      address             city state postal_code   latitude  \
# 0                935 Race St     Philadelphia    PA       19107  39.955505
# 1              615 S Main St     Ashland City    TN       37015  36.269593
# 2          8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 3        2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 4                        NaN        Tampa Bay    FL       33602  27.955269
# ...                      ...              ...   ...         ...        ...
# 52263        19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 52264    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 52265          1108 S 9th St     Philadelphia    PA       19147  39.935982
# 52266        4405 Pennell Rd            Aston    DE       19014  39.856185
# 52267  2470 Guardian Road NW         Edmonton    AB     T5T 1K8  53.509649
#
#         longitude  stars  ...  DietaryRestrictions Corkage HappyHour  \
# 0      -75.155564    4.0  ...                  NaN     NaN       NaN
# 1      -87.058943    2.0  ...                  NaN     NaN     False
# 2      -90.321087    3.0  ...                  NaN     NaN       NaN
# 3      -86.768170    1.5  ...                  NaN     NaN     False
# 4      -82.456320    4.0  ...                  NaN     NaN       NaN
# ...           ...    ...  ...                  ...     ...       ...
# 52263  -75.310344    3.0  ...                  NaN     NaN       NaN
# 52264 -116.284689    4.0  ...                  NaN     NaN       NaN
# 52265  -75.158665    4.5  ...                  NaN     NaN     False
# 52266  -75.427725    4.5  ...                  NaN     NaN       NaN
# 52267 -113.675999    4.5  ...                  NaN     NaN       NaN
#
#       BestNights AgesAllowed Open24Hours GoodForDancing      Alcohol  \
# 0            NaN         NaN         NaN            NaN      u'none'
# 1            NaN         NaN         NaN            NaN      u'none'
# 2            NaN         NaN         NaN            NaN  u'full_bar'
# 3            NaN         NaN         NaN            NaN      u'none'
# 4            NaN         NaN         NaN            NaN       'none'
# ...          ...         ...         ...            ...          ...
# 52263        NaN         NaN         NaN            NaN          NaN
# 52264        NaN         NaN         NaN            NaN      u'none'
# 52265        NaN         NaN         NaN            NaN      u'none'
# 52266        NaN         NaN         NaN            NaN       'none'
# 52267        NaN         NaN         NaN            NaN          NaN
#
#       HairSpecializesIn  NoiseLevel
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                   NaN  u'average'
# 3                   NaN         NaN
# 4                   NaN         NaN
# ...                 ...         ...
# 52263               NaN         NaN
# 52264               NaN     u'loud'
# 52265               NaN         NaN
# 52266               NaN         NaN
# 52267               NaN  u'average'
#
# [52268 rows x 50 columns]

# %%
business_clean=business.drop(columns=["Unnamed: 0","BYOBCorkage","BestNights","AgesAllowed","GoodForDancing"
                                      ,"HairSpecializesIn","Open24Hours","Corkage","DietaryRestrictions",
                                     "Music","CoatCheck","Smoking","Ambience","ByAppointmentOnly","DriveThru",
                                     "BusinessParking","BYOB","GoodForMeal","BusinessAcceptsBitcoin",
                                      "AcceptsInsurance","RestaurantsCounterService","WheelchairAccessible"
                                     ,"RestaurantsTableService","DogsAllowed","HappyHour","BikeParking",
                                      "OutdoorSeating","RestaurantsPriceRange2","Alcohol","NoiseLevel",
                                      "RestaurantsAttire","BusinessAcceptsCreditCards","RestaurantsGoodForGroups"
                                     ,"Caters","WiFi"])
business_clean.to_csv("/Users/bjxl/fyp/csv/business_clean.csv")

# %%
business_clean
# Out:
#                   business_id                           name  \
# 0      MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1      CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 2      k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 3      bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 4      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                       ...                            ...
# 52263  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 52264  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 52265  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 52266  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 52267  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                      address             city state postal_code   latitude  \
# 0                935 Race St     Philadelphia    PA       19107  39.955505
# 1              615 S Main St     Ashland City    TN       37015  36.269593
# 2          8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 3        2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 4                        NaN        Tampa Bay    FL       33602  27.955269
# ...                      ...              ...   ...         ...        ...
# 52263        19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 52264    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 52265          1108 S 9th St     Philadelphia    PA       19147  39.935982
# 52266        4405 Pennell Rd            Aston    DE       19014  39.856185
# 52267  2470 Guardian Road NW         Edmonton    AB     T5T 1K8  53.509649
#
#         longitude  stars  review_count  HasTV RestaurantsTakeOut  \
# 0      -75.155564    4.0            80    NaN               True
# 1      -87.058943    2.0             6   True               True
# 2      -90.321087    3.0            19   True               True
# 3      -86.768170    1.5            10   True               True
# 4      -82.456320    4.0            10    NaN                NaN
# ...           ...    ...           ...    ...                ...
# 52263  -75.310344    3.0            11    NaN               True
# 52264 -116.284689    4.0            33  False              False
# 52265  -75.158665    4.5            35   True               True
# 52266  -75.427725    4.5            14    NaN               True
# 52267 -113.675999    4.5            18    NaN               True
#
#       RestaurantsReservations RestaurantsDelivery GoodForKids
# 0                         NaN               False         NaN
# 1                       False                True        True
# 2                       False               False        True
# 3                       False                True        True
# 4                       False                 NaN         NaN
# ...                       ...                 ...         ...
# 52263                     NaN                True         NaN
# 52264                   False               False        True
# 52265                   False                True        True
# 52266                     NaN               False         NaN
# 52267                     NaN                 NaN        True
#
# [52268 rows x 15 columns]

# %%
business_clean1=business_clean.dropna(axis=0)

# %%
business_clean1
# Out:
#                   business_id                           name  \
# 1      CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 2      k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 3      bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 5      il_Ro8jwPlHresjw9EGmBg                        Denny's
# 6      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# ...                       ...                            ...
# 52260  8n93L-ilMAsvwUatarykSg                    Kitchen Gia
# 52261  2MAQeAqmD8enCT2ZYqUgIQ    The Melting Pot - Nashville
# 52262  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 52264  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 52265  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
#
#                     address          city state postal_code   latitude  \
# 1             615 S Main St  Ashland City    TN       37015  36.269593
# 2         8025 Mackenzie Rd        Affton    MO       63123  38.565165
# 3       2312 Dickerson Pike     Nashville    TN       37207  36.208102
# 5              8901 US 31 S  Indianapolis    IN       46227  39.637133
# 6             2575 E Bay Dr         Largo    FL       33771  27.916116
# ...                     ...           ...   ...         ...        ...
# 52260        3716 Spruce St  Philadelphia    PA       19104  39.951018
# 52261  166 2nd Ave N, Ste A     Nashville    TN       37201  36.163875
# 52262          246 N 8th St         Boise    ID       83702  43.616590
# 52264   1181 N Milwaukee St         Boise    ID       83704  43.615401
# 52265         1108 S 9th St  Philadelphia    PA       19147  39.935982
#
#         longitude  stars  review_count  HasTV RestaurantsTakeOut  \
# 1      -87.058943    2.0             6   True               True
# 2      -90.321087    3.0            19   True               True
# 3      -86.768170    1.5            10   True               True
# 5      -86.127217    2.5            28   True               True
# 6      -82.760461    4.5           100   True               True
# ...           ...    ...           ...    ...                ...
# 52260  -75.198240    3.0            22   True               True
# 52261  -86.776311    4.0           204   True              False
# 52262 -116.202383    4.5           998   True               None
# 52264 -116.284689    4.0            33  False              False
# 52265  -75.158665    4.5            35   True               True
#
#       RestaurantsReservations RestaurantsDelivery GoodForKids
# 1                       False                True        True
# 2                       False               False        True
# 3                       False                True        True
# 5                       False                True        True
# 6                       False                True        True
# ...                       ...                 ...         ...
# 52260                   False                True        True
# 52261                    True               False        True
# 52262                   False                None       False
# 52264                   False               False        True
# 52265                   False                True        True
#
# [35749 rows x 15 columns]

# %%
business_clean2=business_clean1[business_clean1["review_count"]>1000]
business_clean2
# Out:
#                   business_id                         name  \
# 7      MUTTqe8uqyMdBl186RmNeA                     Tuna Bar
# 8      ROeacJQwBeh05Rqg7F6TCg                          BAP
# 11     9OG5YkX1g2GReZM0AskizA      Romano's Macaroni Grill
# 28     seKihQKpGGnCeLuELRQPSQ                   Twin Peaks
# 37     IDtLPgUrqorrpqSLdfMhZQ         Helena Avenue Bakery
# ...                       ...                          ...
# 52237  8MzF1Tlgz0pOkxmhP5dYzA            El Cap Restaurant
# 52238  Ld3qgGua7MqrFnZY8AIo0A                 Café Ventana
# 52253  uriD7RFuHhLJeDdKaf0nFA                   Pizza Guru
# 52261  2MAQeAqmD8enCT2ZYqUgIQ  The Melting Pot - Nashville
# 52262  w_4xUt-1AyY2ZwKtnjW0Xg         Bittercreek Alehouse
#
#                      address            city state postal_code   latitude  \
# 7                205 Race St    Philadelphia    PA       19106  39.953949
# 8              1224 South St    Philadelphia    PA       19147  39.943223
# 11        5505 S Virginia St            Reno    NV       89502  39.476117
# 28            6880 E 82nd St    Indianapolis    IN       46250  39.906295
# 37     131 Anacapa St, Ste C   Santa Barbara    CA       93101  34.414445
# ...                      ...             ...   ...         ...        ...
# 52237          3500 4th St N  St. Petersburg    FL       33704  27.804140
# 52238       3919 W Pine Blvd     Saint Louis    MO       63108  38.638030
# 52253          3534 State St   Santa Barbara    CA       93105  34.440689
# 52261   166 2nd Ave N, Ste A       Nashville    TN       37201  36.163875
# 52262           246 N 8th St           Boise    ID       83702  43.616590
#
#         longitude  stars  review_count  HasTV RestaurantsTakeOut  \
# 7      -75.143226    4.0           245  False               True
# 8      -75.162568    4.5           205   True               True
# 11    -119.789339    2.5           339   True               True
# 28     -86.047463    3.5           257   True               True
# 37    -119.690672    4.0           389  False               True
# ...           ...    ...           ...    ...                ...
# 52237  -82.638855    3.5           414   True               True
# 52238  -90.242133    3.5           290  False               True
# 52253 -119.739681    4.0           299   True               True
# 52261  -86.776311    4.0           204   True              False
# 52262 -116.202383    4.5           998   True               None
#
#       RestaurantsReservations RestaurantsDelivery GoodForKids
# 7                        True                True       False
# 8                       False                None        True
# 11                       True                True        True
# 28                      False               False        True
# 37                      False                None        True
# ...                       ...                 ...         ...
# 52237                   False               False        True
# 52238                   False               False        True
# 52253                   False                True        True
# 52261                    True               False        True
# 52262                   False                None       False
#
# [5237 rows x 15 columns]

# %%
business_clean2.to_csv("/Users/bjxl/fyp/csv/business_clean2.csv")

# %%
business_clean1.to_csv("/Users/bjxl/fyp/csv/business_clean1.csv")
