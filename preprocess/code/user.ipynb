# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import json

# %%
user=[]
path = '/Users/bjxl/yelp_dataset/yelp_academic_dataset_user.json'

with open(path, encoding='utf-8') as fin:
    i = 0
    for line in fin:
        line_contents = json.loads(line)
        user.append(line_contents)

user=pd.DataFrame(user)
user.to_csv('/Users/bjxl/fyp/csv/user.csv')

# %%
user
# Out:
#                         user_id     name  review_count        yelping_since  \
# 0        qVc8ODYU5SZjKXVBgXdI7w   Walker           585  2007-01-25 16:47:26
# 1        j14WgRoU_-2ZE1aw1dXrJg   Daniel          4333  2009-01-25 04:35:42
# 2        2WnXYQFK0hXEoTxPtV2zvg    Steph           665  2008-07-25 10:41:00
# 3        SZDeASXq7o05mMNLshsdIA     Gwen           224  2005-11-29 04:38:33
# 4        hA5lMy-EnncsH4JoR-hFGQ    Karen            79  2007-01-05 19:40:59
# ...                         ...      ...           ...                  ...
# 1987892  fB3jbHi3m0L2KgGOxBv6uw  Jerrold            23  2015-01-06 00:31:31
# 1987893  68czcr4BxJyMQ9cJBm6C7Q     Jane             1  2016-06-14 07:20:52
# 1987894  1x3KMskYxOuJCjRz70xOqQ  Shomari             4  2017-02-04 15:31:58
# 1987895  ulfGl4tdbrH05xKzh5lnog  Susanne             2  2011-01-14 00:29:08
# 1987896  wL5jPrLRVCK_Pmo4lM1zpA      Isa             2  2020-12-19 02:32:39
#
#          useful  funny   cool  \
# ...

# %%
user[user["review_count"]>500].count()
# Out:
# user_id               8570
# name                  8570
# review_count          8570
# yelping_since         8570
# useful                8570
# funny                 8570
# cool                  8570
# elite                 8570
# friends               8570
# fans                  8570
# average_stars         8570
# compliment_hot        8570
# compliment_more       8570
# compliment_profile    8570
# compliment_cute       8570
# compliment_list       8570
# compliment_note       8570
# compliment_plain      8570
# compliment_cool       8570
# compliment_funny      8570
# compliment_writer     8570
# compliment_photos     8570
# dtype: int64

# %%
user_more_than_500=user[user["review_count"]>500]
user_more_than_500.to_csv('/Users/bjxl/fyp/csv/user_review_count_more_than_500.csv')

# %%
user_more_than_500
# Out:
#                         user_id      name  review_count        yelping_since  \
# 0        qVc8ODYU5SZjKXVBgXdI7w    Walker           585  2007-01-25 16:47:26
# 1        j14WgRoU_-2ZE1aw1dXrJg    Daniel          4333  2009-01-25 04:35:42
# 2        2WnXYQFK0hXEoTxPtV2zvg     Steph           665  2008-07-25 10:41:00
# 5        q_QQ5kBBwlCcbL1s4NVK3g      Jane          1221  2005-03-14 20:26:35
# 11       xoZvMJPDW6Q9pDAXI0e_Ww      Ryan           535  2009-05-27 06:12:10
# ...                         ...       ...           ...                  ...
# 1829076  E9T0Irm2d52T2yh1r0DwEA     Susan           553  2012-10-29 04:58:51
# 1832339  evX3hPoTbfcvb_D13O1P2A       Hai           517  2016-04-24 06:22:58
# 1835121  BEEwA-hzBRPxMZi8ilRlMA     Megan           530  2012-02-07 20:49:38
# 1843592  vSVWzD6beYvHjwQ7-FkvWw       Tim           758  2012-10-11 16:40:53
# 1855349  -AL9mIJSpdWHQf4BBeDXgg  Mary Lou           907  2011-05-05 18:33:53
#
#          useful  funny   cool  \
# ...

# %%
restaurant=pd.read_csv("/Users/bjxl/fyp/csv/restaurant_review.csv")
restaurant
# Out:
#        Unnamed: 0             business_id                           name  \
# 0               0  MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1               1  CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 2               2  k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 3               3  bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 4               4  eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...           ...                     ...                            ...
# 52263       52263  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 52264       52264  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 52265       52265  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 52266       52266  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 52267       52267  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                      address             city state postal_code   latitude  \
# ...

# %%
user_review=pd.read_csv('/Users/bjxl/fyp/csv/review.csv')
user_review
# Out:
# /var/folders/cv/j22vlhb52tb_nhwbf2m_cdq40000gn/T/ipykernel_24618/2275033239.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   user_review=pd.read_csv('/Users/bjxl/fyp/csv/review.csv')
#         Unnamed: 0               review_id                 user_id  \
# 0                0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1                1  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 2                2  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 3                3  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# 4                4  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A
# ...            ...                     ...                     ...
# 4724468    4724466  7NgXAuTFiJHYbuepOPwU0w  x1QLCwZGFAjxRRw4EHc3-g
# 4724469    4724467  wD5ZWao_vjyT2h4xmGam8Q  7L7GL5Pi2cf8mbm2Dpw4zw
# 4724470    4724468  YVX1Wsa4LYxjvFwuHBb_gA  RKPkxOYQlM0BjhM-H6_vAw
# ...

# %%
user_review.groupby("user_id").count()
# Out:
#                         Unnamed: 0  review_id  business_id  stars  useful  \
# user_id
# ---2PmXbF47D870stH1jqA          22         22           22     22      22
# ---UgP94gokyCDuB5zUssA          10         10           10     10      10
# ---r61b7EpVPkb4UVme5tA           3          3            3      3       3
# ---zemaUC8WeJeWKqS6p9Q           1          1            1      1       1
# --0DrQkM0FT-yCQRWw82uQ           1          1            1      1       1
# ...                            ...        ...          ...    ...     ...
# zzz-M4QvkEpUWWPL9RTzLA           8          8            8      8       8
# zzzCg-_lpyYE82TlJCdwdw           1          1            1      1       1
# zzzGgfvrSJ4AQeKtcgocIw           1          1            1      1       1
# zzzMBVS73g3ZJ7qL8JyhiA           1          1            1      1       1
# zzzUFM4HFe0SFG0bPjntQA           1          1            1      1       1
#
#                         funny  cool  text  date  polarity
# user_id
# ...

# %%
category=[]
for business_id in user_review["business_id"]:
    i=0
    for restaurant_id in restaurant["business_id"]:
        if business_id==restaurant_id:
            category.append(restaurant["categories"][i])
        i=i+1
category

# %%
num=user_review.groupby("user_id")["review_id"].count()
num
num[num.values>20].to_csv("/Users/bjxl/fyp/csv/1-1.csv")

# %%
num.index
# Out:
# '--17Db1K-KujRuN7hY9Z0Q'

# %%
business_count=[]
for i in num.index:
    k=0
    count=[]
    for j in user_review["user_id"]:
        if i==j:
            count.append(user_review["business_id"][k])
        k=k+1
    business_count.append(count)
business_count
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       3 k=0
#       4 count=[]
# ----> 5 for j in user_review["user_id"]:
#       6     if i==j:
#       7         count.append(user_review["business_id"][k])
#
# KeyboardInterrupt:

# %%
user_review=user_review[["review_id","business_id","user_id","polarity"]]
user_review
# Out:
#                       review_id             business_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  XQfwVwDr-v0ZS3_CbbE5Xw
# 1        saUsX_uimxRlCVr67Z4Jig  YjUWPpI6HXG530lwP-fb2A
# 2        AqPFMleE6RsU23_auESxiA  kxX2SOes4o-D3ZQBkiMRfA
# 3        Sx8TMOWLNuJBWer-0pcmoA  e4Vwtrqf-wpJfwesgvdgxQ
# 4        JrIxlS1TzJ-iCu79ul40cQ  04UD14gamNjLY0IDYVhHJg
# ...                         ...                     ...
# 4724468  7NgXAuTFiJHYbuepOPwU0w  1_BVWDzi5cVqWxNe9bOMMQ
# 4724469  wD5ZWao_vjyT2h4xmGam8Q  e_E-jq9mwm7wk75k7Yi-Xw
# 4724470  YVX1Wsa4LYxjvFwuHBb_gA  X4mouE_cMiwbfyCPZ_K-FA
# 4724471  i-I4ZOhoX70Nw5H0FwrQUA  Rr9kKArrMhSLVE9a53q-aA
# 4724472  RwcKOdEuLRHNJe4M9-qpqg  VAeEXLbEcI9Emt9KGYq9aA
#
#                         user_id  polarity
# 0        mh_-eMZ6K5RLWhZyISBhwA  0.198485
# 1        8g_iMtfSiwikVnbP2etR0A  0.139935
# 2        _7bHUi9Uuf5__HHc_Q8guQ  0.315152
# 3        bcjbaE6dDog4jkNY91ncLQ  0.416234
# 4        eUta8W_HdHMXPzLBBZhL1A  0.211111
# ...

# %%
user_num=user_review.groupby("user_id").count()

# %%
user_restaurant=pd.DataFrame(user_10.index)
user_restaurant["positive"]=[]
user_restaurant["negative"]=[]

# for user_id in user_10.index:
#     i=-1 
#     user_restaurant_positive=[]
#     user_restaurant_negative=[]
#     for user in user_review["user_id"]:
#         i=i+1
#         if user_id==user:
#             if user_review["polarity"][i]>0:
#                 user_restaurant_positive.append(user_review["business_id"][i])
#             else:
#                 user_restaurant_negative.append(user_review["business_id"][i])       
#         user_restaurant["positive"][i]=user_restaurant_positive
#         user_restaurant["negative"][i]=user_restaurant_negative
# user_restaurant_negative               
user_restaurant
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [77], in <cell line: 2>()
#       1 user_restaurant=pd.DataFrame(user_10.index)
# ----> 2 user_restaurant["positive"]=[]
#       3 user_restaurant["negative"]=[]
#       5 # for user_id in user_10.index:
#       6 #     i=-1
#       7 #     user_restaurant_positive=[]
#    (...)
#      17 #         user_restaurant["negative"][i]=user_restaurant_negative
#      18 # user_restaurant_negative
#
# File ~/opt/anaconda3/envs/yelp-dataset/lib/python3.9/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/opt/anaconda3/envs/yelp-dataset/lib/python3.9/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
# ...

# %%
user_review.groupby("user_id")["polarity"].mean()
# Out:
# user_id
# ---2PmXbF47D870stH1jqA    0.370611
# ---UgP94gokyCDuB5zUssA    0.267445
# ---r61b7EpVPkb4UVme5tA    0.273611
# ---zemaUC8WeJeWKqS6p9Q    0.035480
# --0DrQkM0FT-yCQRWw82uQ    0.000000
#                             ...
# zzz-M4QvkEpUWWPL9RTzLA   -0.037194
# zzzCg-_lpyYE82TlJCdwdw    0.668750
# zzzGgfvrSJ4AQeKtcgocIw    0.267014
# zzzMBVS73g3ZJ7qL8JyhiA   -0.050833
# zzzUFM4HFe0SFG0bPjntQA    0.213542
# Name: polarity, Length: 1445991, dtype: float64
